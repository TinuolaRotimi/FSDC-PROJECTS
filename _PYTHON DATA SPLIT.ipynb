# %%
# DATA SPLIT

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel(r'C:\Users\user\Pictures\Downloads\Bangalore_Addresses.xlsx')

# %%
data
# Out:
#                                          Address       Date              Time
# 0    93 6thBlock, Marathahalli, Bangalore-560100  30-Sep-17    5hr 25min 1sec
# 1    96 9thBlock, Marathahalli, Bangalore-560100  25-Nov-17   5hr 23min 35sec
# 2    96 9thBlock, Marathahalli, Bangalore-560100  10-Mar-17    7hr 1min 41sec
# 3    93 6thBlock, Marathahalli, Bangalore-560100  31-Oct-17   3hr 36min 16sec
# 4    94 7thBlock, Marathahalli, Bangalore-560100  06-Dec-17  18hr 46min 57sec
# ..                                           ...        ...               ...
# 995  93 6thBlock, Marathahalli, Bangalore-560100  31-Jan-17   3hr 11min 22sec
# 996  93 6thBlock, Marathahalli, Bangalore-560100  29-Nov-17    6hr 22min 0sec
# 997  93 6thBlock, Marathahalli, Bangalore-560100  13-Sep-17   9hr 39min 13sec
# 998  96 9thBlock, Marathahalli, Bangalore-560100  18-Jan-17   14hr 34min 8sec
# 999  94 7thBlock, Marathahalli, Bangalore-560100  24-Jun-17   9hr 44min 19sec
#
# [1000 rows x 3 columns]

# %%
data.isnull().any().any()
# Out:
# False

# %%
data.columns
# Out:
# Index(['Address', 'Date', 'Time'], dtype='object')

# %%
len(data.columns)
# Out:
# 3

# %%
new_add=data['Address'].str.split(r'[,\s-]+',expand=True)
new_add
# Out:
#       0         1             2          3       4
# 0    93  6thBlock  Marathahalli  Bangalore  560100
# 1    96  9thBlock  Marathahalli  Bangalore  560100
# 2    96  9thBlock  Marathahalli  Bangalore  560100
# 3    93  6thBlock  Marathahalli  Bangalore  560100
# 4    94  7thBlock  Marathahalli  Bangalore  560100
# ..   ..       ...           ...        ...     ...
# 995  93  6thBlock  Marathahalli  Bangalore  560100
# 996  93  6thBlock  Marathahalli  Bangalore  560100
# 997  93  6thBlock  Marathahalli  Bangalore  560100
# 998  96  9thBlock  Marathahalli  Bangalore  560100
# 999  94  7thBlock  Marathahalli  Bangalore  560100
#
# [1000 rows x 5 columns]

# %%
new_add.columns=[['House_No','BlocKNo','Area','City','Zipcode']]
new_add
# Out:
#     House_No   BlocKNo          Area       City Zipcode
# 0         93  6thBlock  Marathahalli  Bangalore  560100
# 1         96  9thBlock  Marathahalli  Bangalore  560100
# 2         96  9thBlock  Marathahalli  Bangalore  560100
# 3         93  6thBlock  Marathahalli  Bangalore  560100
# 4         94  7thBlock  Marathahalli  Bangalore  560100
# ..       ...       ...           ...        ...     ...
# 995       93  6thBlock  Marathahalli  Bangalore  560100
# 996       93  6thBlock  Marathahalli  Bangalore  560100
# 997       93  6thBlock  Marathahalli  Bangalore  560100
# 998       96  9thBlock  Marathahalli  Bangalore  560100
# 999       94  7thBlock  Marathahalli  Bangalore  560100
#
# [1000 rows x 5 columns]

# %%
data.head()
# Out:
#                                        Address       Date              Time
# 0  93 6thBlock, Marathahalli, Bangalore-560100  30-Sep-17    5hr 25min 1sec
# 1  96 9thBlock, Marathahalli, Bangalore-560100  25-Nov-17   5hr 23min 35sec
# 2  96 9thBlock, Marathahalli, Bangalore-560100  10-Mar-17    7hr 1min 41sec
# 3  93 6thBlock, Marathahalli, Bangalore-560100  31-Oct-17   3hr 36min 16sec
# 4  94 7thBlock, Marathahalli, Bangalore-560100  06-Dec-17  18hr 46min 57sec

# %%
new_date=data['Date'].str.split(r'[-]',expand=True)

# %%
new_date
# Out:
#       0    1   2
# 0    30  Sep  17
# 1    25  Nov  17
# 2    10  Mar  17
# 3    31  Oct  17
# 4    06  Dec  17
# ..   ..  ...  ..
# 995  31  Jan  17
# 996  29  Nov  17
# 997  13  Sep  17
# 998  18  Jan  17
# 999  24  Jun  17
#
# [1000 rows x 3 columns]

# %%
new_time=data['Time'].str.split(r'[\s]',expand=True)
new_time
# Out:
#         0      1      2
# 0     5hr  25min   1sec
# 1     5hr  23min  35sec
# 2     7hr   1min  41sec
# 3     3hr  36min  16sec
# 4    18hr  46min  57sec
# ..    ...    ...    ...
# 995   3hr  11min  22sec
# 996   6hr  22min   0sec
# 997   9hr  39min  13sec
# 998  14hr  34min   8sec
# 999   9hr  44min  19sec
#
# [1000 rows x 3 columns]

# %%
new_time.columns=[['Hour','Minutes','Seconds']]
new_time
# Out:
#      Hour Minutes Seconds
# 0     5hr   25min    1sec
# 1     5hr   23min   35sec
# 2     7hr    1min   41sec
# 3     3hr   36min   16sec
# 4    18hr   46min   57sec
# ..    ...     ...     ...
# 995   3hr   11min   22sec
# 996   6hr   22min    0sec
# 997   9hr   39min   13sec
# 998  14hr   34min    8sec
# 999   9hr   44min   19sec
#
# [1000 rows x 3 columns]

# %%
data.head()
# Out:
#                                        Address       Date              Time
# 0  93 6thBlock, Marathahalli, Bangalore-560100  30-Sep-17    5hr 25min 1sec
# 1  96 9thBlock, Marathahalli, Bangalore-560100  25-Nov-17   5hr 23min 35sec
# 2  96 9thBlock, Marathahalli, Bangalore-560100  10-Mar-17    7hr 1min 41sec
# 3  93 6thBlock, Marathahalli, Bangalore-560100  31-Oct-17   3hr 36min 16sec
# 4  94 7thBlock, Marathahalli, Bangalore-560100  06-Dec-17  18hr 46min 57sec

# %%
new_data=pd.concat([new_add,new_date,new_time], axis=1)
new_data
# Out:
#     House_No   BlocKNo          Area       City Zipcode Day Month Year  Hour  \
# 0         93  6thBlock  Marathahalli  Bangalore  560100  30   Sep   17   5hr
# 1         96  9thBlock  Marathahalli  Bangalore  560100  25   Nov   17   5hr
# 2         96  9thBlock  Marathahalli  Bangalore  560100  10   Mar   17   7hr
# 3         93  6thBlock  Marathahalli  Bangalore  560100  31   Oct   17   3hr
# 4         94  7thBlock  Marathahalli  Bangalore  560100  06   Dec   17  18hr
# ..       ...       ...           ...        ...     ...  ..   ...  ...   ...
# 995       93  6thBlock  Marathahalli  Bangalore  560100  31   Jan   17   3hr
# 996       93  6thBlock  Marathahalli  Bangalore  560100  29   Nov   17   6hr
# 997       93  6thBlock  Marathahalli  Bangalore  560100  13   Sep   17   9hr
# 998       96  9thBlock  Marathahalli  Bangalore  560100  18   Jan   17  14hr
# 999       94  7thBlock  Marathahalli  Bangalore  560100  24   Jun   17   9hr
#
#     Minutes Seconds
# 0     25min    1sec
# ...

# %%
new_data.to_excel('output.xlsx', index=False)

# %%
new_data
# Out:
#     House_No   BlocKNo          Area       City Zipcode Day Month Year  Hour  \
# 0         93  6thBlock  Marathahalli  Bangalore  560100  30   Sep   17   5hr
# 1         96  9thBlock  Marathahalli  Bangalore  560100  25   Nov   17   5hr
# 2         96  9thBlock  Marathahalli  Bangalore  560100  10   Mar   17   7hr
# 3         93  6thBlock  Marathahalli  Bangalore  560100  31   Oct   17   3hr
# 4         94  7thBlock  Marathahalli  Bangalore  560100  06   Dec   17  18hr
# ..       ...       ...           ...        ...     ...  ..   ...  ...   ...
# 995       93  6thBlock  Marathahalli  Bangalore  560100  31   Jan   17   3hr
# 996       93  6thBlock  Marathahalli  Bangalore  560100  29   Nov   17   6hr
# 997       93  6thBlock  Marathahalli  Bangalore  560100  13   Sep   17   9hr
# 998       96  9thBlock  Marathahalli  Bangalore  560100  18   Jan   17  14hr
# 999       94  7thBlock  Marathahalli  Bangalore  560100  24   Jun   17   9hr
#
#     Minutes Seconds
# 0     25min    1sec
# ...

# %%
new_data.head()
# Out:
#   House_No   BlocKNo          Area       City Zipcode Day Month Year  Hour  \
# 0       93  6thBlock  Marathahalli  Bangalore  560100  30   Sep   17   5hr
# 1       96  9thBlock  Marathahalli  Bangalore  560100  25   Nov   17   5hr
# 2       96  9thBlock  Marathahalli  Bangalore  560100  10   Mar   17   7hr
# 3       93  6thBlock  Marathahalli  Bangalore  560100  31   Oct   17   3hr
# 4       94  7thBlock  Marathahalli  Bangalore  560100  06   Dec   17  18hr
#
#   Minutes Seconds
# 0   25min    1sec
# 1   23min   35sec
# 2    1min   41sec
# 3   36min   16sec
# 4   46min   57sec
